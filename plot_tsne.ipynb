# %%
import hydra

import os
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
emb_save_path = "/users/minami/dataset/np_files/x_vec/librispeech"
emb_tsne = np.load(os.path.join(emb_save_path, "emb_tsne.npy"))
print(emb_tsne.shape)
# Out:
# (251, 10, 2)

# %%
n_speaker, _, _ = emb_tsne.shape
for i in range(0, n_speaker, 100):
    plt.scatter(emb_tsne[i][:, 0], emb_tsne[i][:, 1], cmap=plt.cm.jet, edgecolors='none', s=30)
plt.colorbar()
plt.show()

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(1, 1, 1)
ax.scatter(
    emb_tsne[0, :, 0], 
    emb_tsne[0, :, 1],
    cmap=
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/minami/Documents/python/x_vector/plot_tsne.ipynb Cell 3' in <cell line: 5>()
#       <a href='vscode-notebook-cell:/Users/minami/Documents/python/x_vector/plot_tsne.ipynb#ch0000004?line=2'>3</a> ax.scatter(emb_tsne[0, :, 0], emb_tsne[0, :, 1])
#       <a href='vscode-notebook-cell:/Users/minami/Documents/python/x_vector/plot_tsne.ipynb#ch0000004?line=3'>4</a> plt.show()
# ----> <a href='vscode-notebook-cell:/Users/minami/Documents/python/x_vector/plot_tsne.ipynb#ch0000004?line=4'>5</a> fig.colorbar()
#
# TypeError: colorbar() missing 1 required positional argument: 'mappable'
